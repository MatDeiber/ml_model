# %%
# %load_ext autoreload
# %autoreload 2

# %%
param_grid = {
    'model__optimizer':['adam','adagrad','sgd'],
    'model__epochs':[125,150,200],
    'model__dropout':[0.12,0.15,0.18,0.25]
}

params_rf = {'model__n_estimators': [180,200,220],
              'model__max_depth':[10,12,14]}

# %%
params = dict(
    random_forest = dict(
        hyper_params =params_rf
    ), 
    keras_v2 = dict(
        hyper_params = param_grid
    )
)
from ml_model.paramtrainer import ParamTrainer
param_trainer = ParamTrainer()
models = param_trainer.train(params)
models
# Out:
# 2022-01-28 09:33:45.802937: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-28 09:33:45.803052: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/mnt/d/Project/Coastal_Web_App/ml_model/notebooks/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/home/mathieu/.pyenv/versions/3.8.12/envs/coastal_app/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py", line 261, in list_experiments
#     experiment = self._get_experiment(exp_id, view_type)
#   File "/home/mathieu/.pyenv/versions/3.8.12/envs/coastal_app/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py", line 344, in _get_experiment
# ...

# %%
models["random_forest"].cv_results_
# Out:
# {'mean_fit_time': array([1.26847334, 1.22819905, 1.3331131 , 1.2035955 , 1.33379617,
#         1.43522463, 1.27617269, 1.41855788, 1.57396379]),
#  'std_fit_time': array([0.10004408, 0.03381592, 0.02986377, 0.02090754, 0.02241128,
#         0.01380879, 0.00459798, 0.00717248, 0.01483834]),
#  'mean_score_time': array([0.04233179, 0.03863449, 0.04170179, 0.04003377, 0.04262381,
#         0.04556084, 0.04194193, 0.04617233, 0.0503047 ]),
#  'std_score_time': array([0.0060456 , 0.0009923 , 0.00055088, 0.0010853 , 0.00041456,
#         0.00047773, 0.00030707, 0.00067242, 0.00033737]),
#  'param_model__max_depth': masked_array(data=[10, 10, 10, 12, 12, 12, 14, 14, 14],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_model__n_estimators': masked_array(data=[180, 200, 220, 180, 200, 220, 180, 200, 220],
# ...

# %%
models["random_forest"].best_score_
# Out:
# -15.9827427352099

# %%
models["keras_v2"].best_score_
# Out:
# -7.8945297289029925
